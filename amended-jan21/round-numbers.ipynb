# %%
import pandas as pd
import numpy as np

# %%
#Make floats display as dollar amounts
pd.options.display.float_format = '${:,.2f}'.format

# %%
#Read in the cleaned data
data = pd.read_csv('cleaned_data.csv', dtype={'zipcode': str})

# %%
#Claims with round number amounts (likely not to be customers)
round_claims = data[data['amount'] % 1000 < 1]
round_claims.sort_values('amount', ascending=False)
# Out:
#                           name      amount zipcode
# 8504                  Thunevin $400,000.00   33350
# 4792                  Keng Ong $340,000.00    19/F
# 3316    Ionia Atlantic Imports $200,000.00   63144
# 523           Atherton Imports $175,000.00   94026
# 466              ARF Financial $135,000.00   94403
# 9060             William Witte  $90,000.00   92651
# 3207                Hillebrand  $53,000.00   21202
# 2297          E. James Langham  $40,000.00   94609
# 2620               Filips Wine  $38,000.00   94300
# 3324       Irvine Wine Imports  $35,000.00   92614
# 1022                Cam Garner  $21,000.00   92067
# 7915               Simon Pharr  $21,000.00   11560
# 8771           Vienna Wine Co.  $20,000.00   94618
# 5178               Leyla Pasic  $20,000.00   e 800
# 9091        Xavier Von Bertrab  $19,000.00   92118
# 2675           Frank Saulsbury  $16,000.00   94708
# 2772              Gary Fordyce  $13,000.00   22201
# ...
